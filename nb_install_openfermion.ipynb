# %%
! pip install openfermionpyscf
! pip install pylatexenc
! pip install ffsim
! pip install symmer
! pip install --upgrade numpy==1.26.4 # downgrade numpy, even though symmer won't be happy
# NOTE: symmer also won't be happy about the older version of qiskit, but it should still work
! pip install "iqm-client[qiskit]"
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: openfermionpyscf in /home/fredd/.local/lib/python3.10/site-packages (0.5)
# Requirement already satisfied: openfermion>=0.5 in /home/fredd/.local/lib/python3.10/site-packages (from openfermionpyscf) (1.6.1)
# Requirement already satisfied: pyscf in /home/fredd/.local/lib/python3.10/site-packages (from openfermionpyscf) (2.8.0)
# Requirement already satisfied: pytest in /home/fredd/.local/lib/python3.10/site-packages (from openfermionpyscf) (7.4.4)
# Requirement already satisfied: cirq-core~=1.0 in /home/fredd/.local/lib/python3.10/site-packages (from openfermion>=0.5->openfermionpyscf) (1.5.0.dev20250119140111)
# Requirement already satisfied: deprecation in /home/fredd/.local/lib/python3.10/site-packages (from openfermion>=0.5->openfermionpyscf) (2.1.0)
# Requirement already satisfied: h5py>=2.8 in /home/fredd/.local/lib/python3.10/site-packages (from openfermion>=0.5->openfermionpyscf) (3.13.0)
# Requirement already satisfied: networkx in /home/fredd/.local/lib/python3.10/site-packages (from openfermion>=0.5->openfermionpyscf) (3.4.1)
# Requirement already satisfied: numpy>=1.11.0 in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from openfermion>=0.5->openfermionpyscf) (1.26.4)
# Requirement already satisfied: pubchempy in /home/fredd/.local/lib/python3.10/site-packages (from openfermion>=0.5->openfermionpyscf) (1.0.4)
# Requirement already satisfied: requests>=2.18 in /home/fredd/.local/lib/python3.10/site-packages (from openfermion>=0.5->openfermionpyscf) (2.32.3)
# Requirement already satisfied: scipy>=1.1.0 in /home/fredd/.local/lib/python3.10/site-packages (from openfermion>=0.5->openfermionpyscf) (1.15.2)
# Requirement already satisfied: sympy in /home/fredd/.local/lib/python3.10/site-packages (from openfermion>=0.5->openfermionpyscf) (1.13.3)
# Requirement already satisfied: attrs>=21.3.0 in /home/fredd/.local/lib/python3.10/site-packages (from cirq-core~=1.0->openfermion>=0.5->openfermionpyscf) (25.3.0)
# Requirement already satisfied: duet>=0.2.8 in /home/fredd/.local/lib/python3.10/site-packages (from cirq-core~=1.0->openfermion>=0.5->openfermionpyscf) (0.2.9)
# Requirement already satisfied: matplotlib~=3.0 in /home/fredd/.local/lib/python3.10/site-packages (from cirq-core~=1.0->openfermion>=0.5->openfermionpyscf) (3.10.1)
# Requirement already satisfied: pandas in /home/fredd/.local/lib/python3.10/site-packages (from cirq-core~=1.0->openfermion>=0.5->openfermionpyscf) (2.2.3)
# Requirement already satisfied: sortedcontainers~=2.0 in /home/fredd/.local/lib/python3.10/site-packages (from cirq-core~=1.0->openfermion>=0.5->openfermionpyscf) (2.4.0)
# Requirement already satisfied: typing-extensions>=4.2 in /home/fredd/.local/lib/python3.10/site-packages (from cirq-core~=1.0->openfermion>=0.5->openfermionpyscf) (4.12.2)
# Requirement already satisfied: tqdm in /home/fredd/.local/lib/python3.10/site-packages (from cirq-core~=1.0->openfermion>=0.5->openfermionpyscf) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/fredd/.local/lib/python3.10/site-packages (from matplotlib~=3.0->cirq-core~=1.0->openfermion>=0.5->openfermionpyscf) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/fredd/.local/lib/python3.10/site-packages (from matplotlib~=3.0->cirq-core~=1.0->openfermion>=0.5->openfermionpyscf) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/fredd/.local/lib/python3.10/site-packages (from matplotlib~=3.0->cirq-core~=1.0->openfermion>=0.5->openfermionpyscf) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/fredd/.local/lib/python3.10/site-packages (from matplotlib~=3.0->cirq-core~=1.0->openfermion>=0.5->openfermionpyscf) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/fredd/.local/lib/python3.10/site-packages (from matplotlib~=3.0->cirq-core~=1.0->openfermion>=0.5->openfermionpyscf) (24.1)
# Requirement already satisfied: pillow>=8 in /home/fredd/.local/lib/python3.10/site-packages (from matplotlib~=3.0->cirq-core~=1.0->openfermion>=0.5->openfermionpyscf) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from matplotlib~=3.0->cirq-core~=1.0->openfermion>=0.5->openfermionpyscf) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/fredd/.local/lib/python3.10/site-packages (from matplotlib~=3.0->cirq-core~=1.0->openfermion>=0.5->openfermionpyscf) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->cirq-core~=1.0->openfermion>=0.5->openfermionpyscf) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/fredd/.local/lib/python3.10/site-packages (from requests>=2.18->openfermion>=0.5->openfermionpyscf) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from requests>=2.18->openfermion>=0.5->openfermionpyscf) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from requests>=2.18->openfermion>=0.5->openfermionpyscf) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from requests>=2.18->openfermion>=0.5->openfermionpyscf) (2025.4.26)
# Requirement already satisfied: pytz>=2020.1 in /home/fredd/.local/lib/python3.10/site-packages (from pandas->cirq-core~=1.0->openfermion>=0.5->openfermionpyscf) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/fredd/.local/lib/python3.10/site-packages (from pandas->cirq-core~=1.0->openfermion>=0.5->openfermionpyscf) (2025.2)
# Requirement already satisfied: setuptools in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from pyscf->openfermionpyscf) (78.1.1)
# Requirement already satisfied: iniconfig in /home/fredd/.local/lib/python3.10/site-packages (from pytest->openfermionpyscf) (2.1.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /home/fredd/.local/lib/python3.10/site-packages (from pytest->openfermionpyscf) (1.5.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /home/fredd/.local/lib/python3.10/site-packages (from pytest->openfermionpyscf) (1.2.2)
# Requirement already satisfied: tomli>=1.0.0 in /home/fredd/.local/lib/python3.10/site-packages (from pytest->openfermionpyscf) (2.2.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/fredd/.local/lib/python3.10/site-packages (from sympy->openfermion>=0.5->openfermionpyscf) (1.3.0)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: pylatexenc in /home/fredd/.local/lib/python3.10/site-packages (2.10)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: ffsim in /home/fredd/.local/lib/python3.10/site-packages (0.0.52)
# Requirement already satisfied: numpy in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from ffsim) (1.26.4)
# Requirement already satisfied: opt-einsum in /home/fredd/.local/lib/python3.10/site-packages (from ffsim) (3.4.0)
# Requirement already satisfied: orjson in /home/fredd/.local/lib/python3.10/site-packages (from ffsim) (3.10.16)
# Requirement already satisfied: pyscf>=2.7 in /home/fredd/.local/lib/python3.10/site-packages (from ffsim) (2.8.0)
# Requirement already satisfied: qiskit>=1.1 in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from ffsim) (1.2.4)
# Requirement already satisfied: scipy in /home/fredd/.local/lib/python3.10/site-packages (from ffsim) (1.15.2)
# Requirement already satisfied: typing-extensions in /home/fredd/.local/lib/python3.10/site-packages (from ffsim) (4.12.2)
# Requirement already satisfied: h5py>=2.7 in /home/fredd/.local/lib/python3.10/site-packages (from pyscf>=2.7->ffsim) (3.13.0)
# Requirement already satisfied: setuptools in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from pyscf>=2.7->ffsim) (78.1.1)
# Requirement already satisfied: rustworkx>=0.15.0 in /home/fredd/.local/lib/python3.10/site-packages (from qiskit>=1.1->ffsim) (0.15.1)
# Requirement already satisfied: sympy>=1.3 in /home/fredd/.local/lib/python3.10/site-packages (from qiskit>=1.1->ffsim) (1.13.3)
# Requirement already satisfied: dill>=0.3 in /home/fredd/.local/lib/python3.10/site-packages (from qiskit>=1.1->ffsim) (0.3.9)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/fredd/.local/lib/python3.10/site-packages (from qiskit>=1.1->ffsim) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /home/fredd/.local/lib/python3.10/site-packages (from qiskit>=1.1->ffsim) (5.4.1)
# Requirement already satisfied: symengine<0.14,>=0.11 in /home/fredd/.local/lib/python3.10/site-packages (from qiskit>=1.1->ffsim) (0.13.0)
# Requirement already satisfied: six>=1.5 in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from python-dateutil>=2.8.0->qiskit>=1.1->ffsim) (1.17.0)
# Requirement already satisfied: pbr>=2.0.0 in /home/fredd/.local/lib/python3.10/site-packages (from stevedore>=3.0.0->qiskit>=1.1->ffsim) (6.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/fredd/.local/lib/python3.10/site-packages (from sympy>=1.3->qiskit>=1.1->ffsim) (1.3.0)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: symmer in /home/fredd/.local/lib/python3.10/site-packages (0.0.9)
# Requirement already satisfied: cirq-core==1.5.0.dev20250119140111 in /home/fredd/.local/lib/python3.10/site-packages (from symmer) (1.5.0.dev20250119140111)
# Requirement already satisfied: myst-nb<0.18.0,>=0.17.2 in /home/fredd/.local/lib/python3.10/site-packages (from symmer) (0.17.2)
# Requirement already satisfied: ncon<2.0.0,>=1.0.0 in /home/fredd/.local/lib/python3.10/site-packages (from symmer) (1.0.0)
# Requirement already satisfied: numba==0.61.0 in /home/fredd/.local/lib/python3.10/site-packages (from symmer) (0.61.0)
# Collecting numpy<3.0,>=2.1 (from symmer)
#   Using cached numpy-2.2.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: openfermion<2.0.0,>=1.6.1 in /home/fredd/.local/lib/python3.10/site-packages (from symmer) (1.6.1)
# Requirement already satisfied: opt-einsum<4.0.0,>=3.3.0 in /home/fredd/.local/lib/python3.10/site-packages (from symmer) (3.4.0)
# Requirement already satisfied: pydocstyle<7.0.0,>=6.1.1 in /home/fredd/.local/lib/python3.10/site-packages (from symmer) (6.3.0)
# Requirement already satisfied: pytest<8.0.0,>=7.2.2 in /home/fredd/.local/lib/python3.10/site-packages (from symmer) (7.4.4)
# Collecting qiskit<2.0.0,>=1.3.2 (from symmer)
#   Using cached qiskit-1.4.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: quimb<2.0.0,>=1.7.3 in /home/fredd/.local/lib/python3.10/site-packages (from symmer) (1.10.0)
# Requirement already satisfied: scipy<2.0.0,>=1.15.0 in /home/fredd/.local/lib/python3.10/site-packages (from symmer) (1.15.2)
# Requirement already satisfied: attrs>=21.3.0 in /home/fredd/.local/lib/python3.10/site-packages (from cirq-core==1.5.0.dev20250119140111->symmer) (25.3.0)
# Requirement already satisfied: duet>=0.2.8 in /home/fredd/.local/lib/python3.10/site-packages (from cirq-core==1.5.0.dev20250119140111->symmer) (0.2.9)
# Requirement already satisfied: matplotlib~=3.0 in /home/fredd/.local/lib/python3.10/site-packages (from cirq-core==1.5.0.dev20250119140111->symmer) (3.10.1)
# Requirement already satisfied: networkx>=2.4 in /home/fredd/.local/lib/python3.10/site-packages (from cirq-core==1.5.0.dev20250119140111->symmer) (3.4.1)
# Requirement already satisfied: pandas in /home/fredd/.local/lib/python3.10/site-packages (from cirq-core==1.5.0.dev20250119140111->symmer) (2.2.3)
# Requirement already satisfied: sortedcontainers~=2.0 in /home/fredd/.local/lib/python3.10/site-packages (from cirq-core==1.5.0.dev20250119140111->symmer) (2.4.0)
# Requirement already satisfied: sympy in /home/fredd/.local/lib/python3.10/site-packages (from cirq-core==1.5.0.dev20250119140111->symmer) (1.13.3)
# Requirement already satisfied: typing-extensions>=4.2 in /home/fredd/.local/lib/python3.10/site-packages (from cirq-core==1.5.0.dev20250119140111->symmer) (4.12.2)
# Requirement already satisfied: tqdm in /home/fredd/.local/lib/python3.10/site-packages (from cirq-core==1.5.0.dev20250119140111->symmer) (4.67.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /home/fredd/.local/lib/python3.10/site-packages (from numba==0.61.0->symmer) (0.44.0)
# Collecting numpy<3.0,>=2.1 (from symmer)
#   Using cached numpy-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/fredd/.local/lib/python3.10/site-packages (from matplotlib~=3.0->cirq-core==1.5.0.dev20250119140111->symmer) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/fredd/.local/lib/python3.10/site-packages (from matplotlib~=3.0->cirq-core==1.5.0.dev20250119140111->symmer) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/fredd/.local/lib/python3.10/site-packages (from matplotlib~=3.0->cirq-core==1.5.0.dev20250119140111->symmer) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/fredd/.local/lib/python3.10/site-packages (from matplotlib~=3.0->cirq-core==1.5.0.dev20250119140111->symmer) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/fredd/.local/lib/python3.10/site-packages (from matplotlib~=3.0->cirq-core==1.5.0.dev20250119140111->symmer) (24.1)
# Requirement already satisfied: pillow>=8 in /home/fredd/.local/lib/python3.10/site-packages (from matplotlib~=3.0->cirq-core==1.5.0.dev20250119140111->symmer) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from matplotlib~=3.0->cirq-core==1.5.0.dev20250119140111->symmer) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/fredd/.local/lib/python3.10/site-packages (from matplotlib~=3.0->cirq-core==1.5.0.dev20250119140111->symmer) (2.9.0.post0)
# Requirement already satisfied: importlib_metadata in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from myst-nb<0.18.0,>=0.17.2->symmer) (8.6.1)
# Requirement already satisfied: ipython in /home/fredd/.local/lib/python3.10/site-packages (from myst-nb<0.18.0,>=0.17.2->symmer) (8.34.0)
# Requirement already satisfied: jupyter-cache<0.7,>=0.5 in /home/fredd/.local/lib/python3.10/site-packages (from myst-nb<0.18.0,>=0.17.2->symmer) (0.6.1)
# Requirement already satisfied: nbclient in /home/fredd/.local/lib/python3.10/site-packages (from myst-nb<0.18.0,>=0.17.2->symmer) (0.7.4)
# Requirement already satisfied: myst-parser~=0.18.0 in /home/fredd/.local/lib/python3.10/site-packages (from myst-nb<0.18.0,>=0.17.2->symmer) (0.18.1)
# Requirement already satisfied: nbformat~=5.0 in /home/fredd/.local/lib/python3.10/site-packages (from myst-nb<0.18.0,>=0.17.2->symmer) (5.10.4)
# Requirement already satisfied: pyyaml in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from myst-nb<0.18.0,>=0.17.2->symmer) (6.0)
# Requirement already satisfied: sphinx<6,>=4 in /home/fredd/.local/lib/python3.10/site-packages (from myst-nb<0.18.0,>=0.17.2->symmer) (5.3.0)
# Requirement already satisfied: ipykernel in /home/fredd/.local/lib/python3.10/site-packages (from myst-nb<0.18.0,>=0.17.2->symmer) (6.29.5)
# Requirement already satisfied: click in /home/fredd/.local/lib/python3.10/site-packages (from jupyter-cache<0.7,>=0.5->myst-nb<0.18.0,>=0.17.2->symmer) (8.1.8)
# Requirement already satisfied: sqlalchemy<3,>=1.3.12 in /home/fredd/.local/lib/python3.10/site-packages (from jupyter-cache<0.7,>=0.5->myst-nb<0.18.0,>=0.17.2->symmer) (2.0.40)
# Requirement already satisfied: tabulate in /home/fredd/.local/lib/python3.10/site-packages (from jupyter-cache<0.7,>=0.5->myst-nb<0.18.0,>=0.17.2->symmer) (0.9.0)
# Requirement already satisfied: docutils<0.20,>=0.15 in /home/fredd/.local/lib/python3.10/site-packages (from myst-parser~=0.18.0->myst-nb<0.18.0,>=0.17.2->symmer) (0.19)
# Requirement already satisfied: jinja2 in /home/fredd/.local/lib/python3.10/site-packages (from myst-parser~=0.18.0->myst-nb<0.18.0,>=0.17.2->symmer) (3.1.6)
# Requirement already satisfied: markdown-it-py<3.0.0,>=1.0.0 in /home/fredd/.local/lib/python3.10/site-packages (from myst-parser~=0.18.0->myst-nb<0.18.0,>=0.17.2->symmer) (2.2.0)
# Requirement already satisfied: mdit-py-plugins~=0.3.1 in /home/fredd/.local/lib/python3.10/site-packages (from myst-parser~=0.18.0->myst-nb<0.18.0,>=0.17.2->symmer) (0.3.5)
# Requirement already satisfied: mdurl~=0.1 in /home/fredd/.local/lib/python3.10/site-packages (from markdown-it-py<3.0.0,>=1.0.0->myst-parser~=0.18.0->myst-nb<0.18.0,>=0.17.2->symmer) (0.1.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/fredd/.local/lib/python3.10/site-packages (from nbclient->myst-nb<0.18.0,>=0.17.2->symmer) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/fredd/.local/lib/python3.10/site-packages (from nbclient->myst-nb<0.18.0,>=0.17.2->symmer) (5.7.2)
# Requirement already satisfied: traitlets>=5.3 in /home/fredd/.local/lib/python3.10/site-packages (from nbclient->myst-nb<0.18.0,>=0.17.2->symmer) (5.14.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/fredd/.local/lib/python3.10/site-packages (from nbformat~=5.0->myst-nb<0.18.0,>=0.17.2->symmer) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /home/fredd/.local/lib/python3.10/site-packages (from nbformat~=5.0->myst-nb<0.18.0,>=0.17.2->symmer) (4.23.0)
# Requirement already satisfied: deprecation in /home/fredd/.local/lib/python3.10/site-packages (from openfermion<2.0.0,>=1.6.1->symmer) (2.1.0)
# Requirement already satisfied: h5py>=2.8 in /home/fredd/.local/lib/python3.10/site-packages (from openfermion<2.0.0,>=1.6.1->symmer) (3.13.0)
# Requirement already satisfied: pubchempy in /home/fredd/.local/lib/python3.10/site-packages (from openfermion<2.0.0,>=1.6.1->symmer) (1.0.4)
# Requirement already satisfied: requests>=2.18 in /home/fredd/.local/lib/python3.10/site-packages (from openfermion<2.0.0,>=1.6.1->symmer) (2.32.3)
# Requirement already satisfied: snowballstemmer>=2.2.0 in /home/fredd/.local/lib/python3.10/site-packages (from pydocstyle<7.0.0,>=6.1.1->symmer) (2.2.0)
# Requirement already satisfied: iniconfig in /home/fredd/.local/lib/python3.10/site-packages (from pytest<8.0.0,>=7.2.2->symmer) (2.1.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /home/fredd/.local/lib/python3.10/site-packages (from pytest<8.0.0,>=7.2.2->symmer) (1.5.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /home/fredd/.local/lib/python3.10/site-packages (from pytest<8.0.0,>=7.2.2->symmer) (1.2.2)
# Requirement already satisfied: tomli>=1.0.0 in /home/fredd/.local/lib/python3.10/site-packages (from pytest<8.0.0,>=7.2.2->symmer) (2.2.1)
# Requirement already satisfied: rustworkx>=0.15.0 in /home/fredd/.local/lib/python3.10/site-packages (from qiskit<2.0.0,>=1.3.2->symmer) (0.15.1)
# Requirement already satisfied: dill>=0.3 in /home/fredd/.local/lib/python3.10/site-packages (from qiskit<2.0.0,>=1.3.2->symmer) (0.3.9)
# Requirement already satisfied: stevedore>=3.0.0 in /home/fredd/.local/lib/python3.10/site-packages (from qiskit<2.0.0,>=1.3.2->symmer) (5.4.1)
# Requirement already satisfied: symengine<0.14,>=0.11 in /home/fredd/.local/lib/python3.10/site-packages (from qiskit<2.0.0,>=1.3.2->symmer) (0.13.0)
# Requirement already satisfied: autoray>=0.6.12 in /home/fredd/.local/lib/python3.10/site-packages (from quimb<2.0.0,>=1.7.3->symmer) (0.6.12)
# Requirement already satisfied: cotengra>=0.6.1 in /home/fredd/.local/lib/python3.10/site-packages (from quimb<2.0.0,>=1.7.3->symmer) (0.7.2)
# Requirement already satisfied: cytoolz>=0.8.0 in /home/fredd/.local/lib/python3.10/site-packages (from quimb<2.0.0,>=1.7.3->symmer) (1.0.1)
# Requirement already satisfied: psutil>=4.3.1 in /home/fredd/.local/lib/python3.10/site-packages (from quimb<2.0.0,>=1.7.3->symmer) (7.0.0)
# Requirement already satisfied: sphinxcontrib-applehelp in /home/fredd/.local/lib/python3.10/site-packages (from sphinx<6,>=4->myst-nb<0.18.0,>=0.17.2->symmer) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp in /home/fredd/.local/lib/python3.10/site-packages (from sphinx<6,>=4->myst-nb<0.18.0,>=0.17.2->symmer) (2.0.0)
# Requirement already satisfied: sphinxcontrib-jsmath in /home/fredd/.local/lib/python3.10/site-packages (from sphinx<6,>=4->myst-nb<0.18.0,>=0.17.2->symmer) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /home/fredd/.local/lib/python3.10/site-packages (from sphinx<6,>=4->myst-nb<0.18.0,>=0.17.2->symmer) (2.1.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /home/fredd/.local/lib/python3.10/site-packages (from sphinx<6,>=4->myst-nb<0.18.0,>=0.17.2->symmer) (2.0.0)
# Requirement already satisfied: sphinxcontrib-qthelp in /home/fredd/.local/lib/python3.10/site-packages (from sphinx<6,>=4->myst-nb<0.18.0,>=0.17.2->symmer) (2.0.0)
# Requirement already satisfied: Pygments>=2.12 in /home/fredd/.local/lib/python3.10/site-packages (from sphinx<6,>=4->myst-nb<0.18.0,>=0.17.2->symmer) (2.19.1)
# Requirement already satisfied: babel>=2.9 in /home/fredd/.local/lib/python3.10/site-packages (from sphinx<6,>=4->myst-nb<0.18.0,>=0.17.2->symmer) (2.17.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /home/fredd/.local/lib/python3.10/site-packages (from sphinx<6,>=4->myst-nb<0.18.0,>=0.17.2->symmer) (0.7.16)
# Requirement already satisfied: imagesize>=1.3 in /home/fredd/.local/lib/python3.10/site-packages (from sphinx<6,>=4->myst-nb<0.18.0,>=0.17.2->symmer) (1.4.1)
# Requirement already satisfied: greenlet>=1 in /home/fredd/.local/lib/python3.10/site-packages (from sqlalchemy<3,>=1.3.12->jupyter-cache<0.7,>=0.5->myst-nb<0.18.0,>=0.17.2->symmer) (3.2.0)
# Requirement already satisfied: toolz>=0.8.0 in /home/fredd/.local/lib/python3.10/site-packages (from cytoolz>=0.8.0->quimb<2.0.0,>=1.7.3->symmer) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/fredd/.local/lib/python3.10/site-packages (from jinja2->myst-parser~=0.18.0->myst-nb<0.18.0,>=0.17.2->symmer) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/fredd/.local/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat~=5.0->myst-nb<0.18.0,>=0.17.2->symmer) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/fredd/.local/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat~=5.0->myst-nb<0.18.0,>=0.17.2->symmer) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/fredd/.local/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat~=5.0->myst-nb<0.18.0,>=0.17.2->symmer) (0.23.1)
# Requirement already satisfied: pyzmq>=23.0 in /home/fredd/.local/lib/python3.10/site-packages (from jupyter-client>=6.1.12->nbclient->myst-nb<0.18.0,>=0.17.2->symmer) (26.3.0)
# Requirement already satisfied: tornado>=6.2 in /home/fredd/.local/lib/python3.10/site-packages (from jupyter-client>=6.1.12->nbclient->myst-nb<0.18.0,>=0.17.2->symmer) (6.4.2)
# Requirement already satisfied: platformdirs>=2.5 in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->nbclient->myst-nb<0.18.0,>=0.17.2->symmer) (4.3.7)
# Requirement already satisfied: six>=1.5 in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->cirq-core==1.5.0.dev20250119140111->symmer) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/fredd/.local/lib/python3.10/site-packages (from requests>=2.18->openfermion<2.0.0,>=1.6.1->symmer) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from requests>=2.18->openfermion<2.0.0,>=1.6.1->symmer) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from requests>=2.18->openfermion<2.0.0,>=1.6.1->symmer) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from requests>=2.18->openfermion<2.0.0,>=1.6.1->symmer) (2025.4.26)
# Requirement already satisfied: pbr>=2.0.0 in /home/fredd/.local/lib/python3.10/site-packages (from stevedore>=3.0.0->qiskit<2.0.0,>=1.3.2->symmer) (6.1.1)
# Requirement already satisfied: setuptools in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit<2.0.0,>=1.3.2->symmer) (78.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/fredd/.local/lib/python3.10/site-packages (from sympy->cirq-core==1.5.0.dev20250119140111->symmer) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from importlib_metadata->myst-nb<0.18.0,>=0.17.2->symmer) (3.21.0)
# Requirement already satisfied: comm>=0.1.1 in /home/fredd/.local/lib/python3.10/site-packages (from ipykernel->myst-nb<0.18.0,>=0.17.2->symmer) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/fredd/.local/lib/python3.10/site-packages (from ipykernel->myst-nb<0.18.0,>=0.17.2->symmer) (1.8.13)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/fredd/.local/lib/python3.10/site-packages (from ipykernel->myst-nb<0.18.0,>=0.17.2->symmer) (0.1.7)
# Requirement already satisfied: nest-asyncio in /home/fredd/.local/lib/python3.10/site-packages (from ipykernel->myst-nb<0.18.0,>=0.17.2->symmer) (1.6.0)
# Requirement already satisfied: decorator in /home/fredd/.local/lib/python3.10/site-packages (from ipython->myst-nb<0.18.0,>=0.17.2->symmer) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /home/fredd/.local/lib/python3.10/site-packages (from ipython->myst-nb<0.18.0,>=0.17.2->symmer) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from ipython->myst-nb<0.18.0,>=0.17.2->symmer) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/fredd/.local/lib/python3.10/site-packages (from ipython->myst-nb<0.18.0,>=0.17.2->symmer) (3.0.50)
# Requirement already satisfied: stack_data in /home/fredd/.local/lib/python3.10/site-packages (from ipython->myst-nb<0.18.0,>=0.17.2->symmer) (0.6.3)
# Requirement already satisfied: wcwidth in /home/fredd/.local/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->myst-nb<0.18.0,>=0.17.2->symmer) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/fredd/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython->myst-nb<0.18.0,>=0.17.2->symmer) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from pexpect>4.3->ipython->myst-nb<0.18.0,>=0.17.2->symmer) (0.7.0)
# Requirement already satisfied: pytz>=2020.1 in /home/fredd/.local/lib/python3.10/site-packages (from pandas->cirq-core==1.5.0.dev20250119140111->symmer) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/fredd/.local/lib/python3.10/site-packages (from pandas->cirq-core==1.5.0.dev20250119140111->symmer) (2025.2)
# Requirement already satisfied: executing>=1.2.0 in /home/fredd/.local/lib/python3.10/site-packages (from stack_data->ipython->myst-nb<0.18.0,>=0.17.2->symmer) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/fredd/.local/lib/python3.10/site-packages (from stack_data->ipython->myst-nb<0.18.0,>=0.17.2->symmer) (3.0.0)
# Requirement already satisfied: pure-eval in /home/fredd/.local/lib/python3.10/site-packages (from stack_data->ipython->myst-nb<0.18.0,>=0.17.2->symmer) (0.2.3)
# Using cached numpy-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
# Using cached qiskit-1.4.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.8 MB)
# Installing collected packages: numpy, qiskit
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: qiskit━━━━━━━━━━━━━━━━━━ 0/2 [numpy]
#     Found existing installation: qiskit 1.2.4 0/2 [numpy]
#     Uninstalling qiskit-1.2.4:━━━━━━━━━━━━━━ 0/2 [numpy]
#       Successfully uninstalled qiskit-1.2.4━ 0/2 [numpy]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [qiskit]2m1/2 [qiskit]
# Successfully installed numpy-2.1.3 qiskit-1.4.2
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.3
#     Uninstalling numpy-2.1.3:
#       Successfully uninstalled numpy-2.1.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# symmer 0.0.9 requires numpy<3.0,>=2.1, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Requirement already satisfied: iqm-client[qiskit] in /home/fredd/.local/lib/python3.10/site-packages (23.8)
# Requirement already satisfied: numpy<3.0,>=1.25.2 in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from iqm-client[qiskit]) (1.26.4)
# Requirement already satisfied: packaging==24.1 in /home/fredd/.local/lib/python3.10/site-packages (from iqm-client[qiskit]) (24.1)
# Requirement already satisfied: pydantic<3.0,>=2.9.2 in /home/fredd/.local/lib/python3.10/site-packages (from iqm-client[qiskit]) (2.11.3)
# Requirement already satisfied: requests==2.32.3 in /home/fredd/.local/lib/python3.10/site-packages (from iqm-client[qiskit]) (2.32.3)
# Collecting qiskit<1.3,>=1.0 (from iqm-client[qiskit])
#   Using cached qiskit-1.2.4-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: qiskit-aer<0.16,>=0.13.1 in /home/fredd/.local/lib/python3.10/site-packages (from iqm-client[qiskit]) (0.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/fredd/.local/lib/python3.10/site-packages (from requests==2.32.3->iqm-client[qiskit]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from requests==2.32.3->iqm-client[qiskit]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from requests==2.32.3->iqm-client[qiskit]) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from requests==2.32.3->iqm-client[qiskit]) (2025.4.26)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/fredd/.local/lib/python3.10/site-packages (from pydantic<3.0,>=2.9.2->iqm-client[qiskit]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /home/fredd/.local/lib/python3.10/site-packages (from pydantic<3.0,>=2.9.2->iqm-client[qiskit]) (2.33.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/fredd/.local/lib/python3.10/site-packages (from pydantic<3.0,>=2.9.2->iqm-client[qiskit]) (4.12.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/fredd/.local/lib/python3.10/site-packages (from pydantic<3.0,>=2.9.2->iqm-client[qiskit]) (0.4.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /home/fredd/.local/lib/python3.10/site-packages (from qiskit<1.3,>=1.0->iqm-client[qiskit]) (0.15.1)
# Requirement already satisfied: scipy>=1.5 in /home/fredd/.local/lib/python3.10/site-packages (from qiskit<1.3,>=1.0->iqm-client[qiskit]) (1.15.2)
# Requirement already satisfied: sympy>=1.3 in /home/fredd/.local/lib/python3.10/site-packages (from qiskit<1.3,>=1.0->iqm-client[qiskit]) (1.13.3)
# Requirement already satisfied: dill>=0.3 in /home/fredd/.local/lib/python3.10/site-packages (from qiskit<1.3,>=1.0->iqm-client[qiskit]) (0.3.9)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/fredd/.local/lib/python3.10/site-packages (from qiskit<1.3,>=1.0->iqm-client[qiskit]) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /home/fredd/.local/lib/python3.10/site-packages (from qiskit<1.3,>=1.0->iqm-client[qiskit]) (5.4.1)
# Requirement already satisfied: symengine<0.14,>=0.11 in /home/fredd/.local/lib/python3.10/site-packages (from qiskit<1.3,>=1.0->iqm-client[qiskit]) (0.13.0)
# Requirement already satisfied: psutil>=5 in /home/fredd/.local/lib/python3.10/site-packages (from qiskit-aer<0.16,>=0.13.1->iqm-client[qiskit]) (7.0.0)
# Requirement already satisfied: six>=1.5 in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from python-dateutil>=2.8.0->qiskit<1.3,>=1.0->iqm-client[qiskit]) (1.17.0)
# Requirement already satisfied: pbr>=2.0.0 in /home/fredd/.local/lib/python3.10/site-packages (from stevedore>=3.0.0->qiskit<1.3,>=1.0->iqm-client[qiskit]) (6.1.1)
# Requirement already satisfied: setuptools in /home/fredd/miniconda3/envs/qsci/lib/python3.10/site-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit<1.3,>=1.0->iqm-client[qiskit]) (78.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/fredd/.local/lib/python3.10/site-packages (from sympy>=1.3->qiskit<1.3,>=1.0->iqm-client[qiskit]) (1.3.0)
# Using cached qiskit-1.2.4-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
# Installing collected packages: qiskit
#   Attempting uninstall: qiskit
#     Found existing installation: qiskit 1.4.2
#     Uninstalling qiskit-1.4.2:
#       Successfully uninstalled qiskit-1.4.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# symmer 0.0.9 requires numpy<3.0,>=2.1, but you have numpy 1.26.4 which is incompatible.
# symmer 0.0.9 requires qiskit<2.0.0,>=1.3.2, but you have qiskit 1.2.4 which is incompatible.
# Successfully installed qiskit-1.2.4
